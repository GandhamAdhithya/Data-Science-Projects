# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\Adhithya\anaconda3\Lib\site-packages\seaborn\_statistics.py:32: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.5.1)
#   from scipy.stats import gaussian_kde

# %%
df=pd.read_csv(r"D:\heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
len(df)
# Out:
# 918

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# # Age(DistPlot)

# %%
sns.displot(df["Age"],kde=True)

# %%
sns.distplot(df["Age"],kde=True,hist=True,rug=True)
# Out:
# C:\Users\Adhithya\AppData\Local\Temp\ipykernel_16700\669946434.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"],kde=True,hist=True,rug=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # Categorical Column(PieCharts)

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.groupby("Sex").size().plot(kind="pie",autopct="%1.2f%%")
# Out:
# <Axes: >

# %%
df.groupby("ChestPainType").size().plot(kind="pie",autopct="%1.2f%%")
# Out:
# <Axes: >

# %%
df.groupby("RestingECG").size().plot(kind="pie",autopct="%1.2f%%")
# Out:
# <Axes: >

# %%
df.groupby("ExerciseAngina").size().plot(kind="pie",autopct="%1.2f%%")
# Out:
# <Axes: >

# %%
df.groupby("ST_Slope").size().plot(kind="pie",autopct="%1.2f%%")
# Out:
# <Axes: >

# %% [markdown]
# # Violin Plot

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
sns.violinplot(x=df["Age"])
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# ### Here we analyzing how many males or females having Heart Disease using violin plot

# %%
sns.violinplot(x=df["HeartDisease"],y=df["Sex"],color="orange")    # 0->indicates negativeCases(No disease) 1->indicates positive
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(x=df["HeartDisease"],y=df["Age"],color="orange")
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(x=df["HeartDisease"],y=df["Age"],color="orange",hue=df["Sex"])
# Out:
# C:\Users\Adhithya\AppData\Local\Temp\ipykernel_16700\1908809950.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:orange'` for the same effect.
#
#   sns.violinplot(x=df["HeartDisease"],y=df["Age"],color="orange",hue=df["Sex"])
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(x=df["HeartDisease"],y=df["Cholesterol"],color="orange")
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %% [markdown]
# # Correlation

# %% [markdown]
# ## 1.Heat Map

# %%
df.corr(numeric_only=True)
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),cmap="Blues",annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## 2. JointPlot

# %% [markdown]
# #### There is a negative correlation between age and maxHR let see how it is using joint plot

# %%
sns.jointplot(x="Age",y="MaxHR",data=df)

# %%
sns.jointplot(x="Age",y="MaxHR",data=df,kind="hex")

# %%
sns.jointplot(x="Age",y="MaxHR",data=df,kind="reg")

# %%
sns.jointplot(x="Age",y="Age",data=df)

# %%
sns.jointplot(x="HeartDisease",y="Oldpeak",data=df)

# %%
sns.jointplot(x="Cholesterol",y="Oldpeak",data=df,kind="reg")

# %% [markdown]
# ## 3. PairPlot

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,kind="reg")
