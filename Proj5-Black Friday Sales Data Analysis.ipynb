# %% [markdown]
# # 1.Walk-Through

# %%
import pandas as pd
import seaborn as sns
# Out:
# C:\Users\Adhithya\anaconda3\Lib\site-packages\seaborn\_statistics.py:32: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.5.1)
#   from scipy.stats import gaussian_kde

# %%
df=pd.read_csv(r"D:\BlackFriday.csv")
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  str
#  2   Gender                      537577 non-null  str
#  3   Age                         537577 non-null  str
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  str
#  6   Stay_In_Current_City_Years  537577 non-null  str
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), str(5)
# memory usage: 57.9 MB

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %% [markdown]
# #### Here Two columns are having more null values instead of dropping all rows i delete only those two columns it better because
# #### if we delete total rows of null values we lost more amount of data so thats why we delete only those two columns

# %%
del df["Product_Category_2"]
del df["Product_Category_3"]

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# # 2.Analyzing columns

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %% [markdown]
# ### Finding How Many unique user_ids in dataset

# %%
df["User_ID"].nunique()
# Out:
# 5891

# %%
df["User_ID"].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       shape=(5891,))

# %% [markdown]
# ### Finding How Many unique Product_ids in dataset

# %%
df["Product_ID"].nunique()
# Out:
# 3623

# %%
df["Product_ID"].unique()
# Out:
# <ArrowStringArray>
# ['P00069042', 'P00248942', 'P00087842', 'P00085442', 'P00285442', 'P00193542',
#  'P00184942', 'P00346142',  'P0097242', 'P00274942',
#  ...
#  'P00315142', 'P00365942', 'P00056642', 'P00104042', 'P00208642', 'P00065942',
#  'P00329042', 'P00038842', 'P00295642', 'P00091742']
# Length: 3623, dtype: str

# %% [markdown]
# ### Finding  unique Gender Types in dataset

# %%
df["Gender"].nunique()
# Out:
# 2

# %%
df["Gender"].unique()
# Out:
# <ArrowStringArray>
# ['F', 'M']
# Length: 2, dtype: str

# %% [markdown]
# ### Finding How Many Different Age persons in dataset

# %%
df["Age"].nunique()
# Out:
# 7

# %%
df["Age"].unique()
# Out:
# <ArrowStringArray>
# ['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25']
# Length: 7, dtype: str

# %% [markdown]
# ### Finding How Many unique Occupations in dataset

# %%
df["Occupation"].nunique()
# Out:
# 21

# %%
df["Occupation"].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %% [markdown]
# ### Finding How Much Total income the company or supermarket get in dataset

# %%
print(df["Purchase"].sum() )
# Out:
# 5017668378

# %% [markdown]
# ### Simple way to find all columns in one step

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Purchase'],
#       dtype='str')

# %%
for column in df.columns:
    print(column,"-",df[column].nunique())
# Out:
# User_ID - 5891
# Product_ID - 3623
# Gender - 2
# Age - 7
# Occupation - 21
# City_Category - 3
# Stay_In_Current_City_Years - 5
# Marital_Status - 2
# Product_Category_1 - 18
# Purchase - 17959

# %% [markdown]
# #
# 3.Analyzing Gender

# %%
df[df["Gender"]=="M"]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4                              4+               0                   8
# ...

# %% [markdown]
# ### How many males and Females are purchasing products

# %%
len(df[df["Gender"]=="M"]),len(df[df["Gender"]=="F"])
# Out:
# (405380, 132197)

# %%
data=pd.DataFrame({'Ratio' :[len(df[df["Gender"]=="M"]),len(df[df["Gender"]=="F"])]},index=["Male","Female"])

# %%
data.plot.pie(y="Ratio",autopct="%1.f%%",figsize=(5,5))
# Out:
# <Axes: >

# %%
#Another method 
df.groupby("Gender").size().plot(kind="pie",autopct="%1.f%%",title="Gender Ratio(%)")
# Out:
# <Axes: title={'center': 'Gender Ratio(%)'}>

# %% [markdown]
# ### How much total cost spend by male and female to purchase products?

# %%
df.groupby("Gender")["Purchase"].sum()
# Out:
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
df.groupby("Gender")["Purchase"].sum().plot(kind="pie",autopct="%1.f%%")
# Out:
# <Axes: >

# %%
df.groupby("Gender")["Purchase"].mean().plot(kind="pie",autopct="%1.2f%%")
# Out:
# <Axes: >

# %% [markdown]
# # Analyzing Age & Martial Status

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %% [markdown]
# ### Finding how Many purchases done by different age groups

# %%
df.groupby("Age").size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
df.groupby("Age").size().plot(kind="bar",figsize=(12,6),title="Purchase Distribution By Age")
# Out:
# <Axes: title={'center': 'Purchase Distribution By Age'}, xlabel='Age'>

# %%
len(df[df["Age"]=="0-17"])
# Out:
# 14707

# %%
for i in df["Age"].unique():
    print(i,":",len(df[df["Age"]==i]))
# Out:
# 0-17 : 14707
# 55+ : 20903
# 26-35 : 214690
# 46-50 : 44526
# 51-55 : 37618
# 36-45 : 107499
# 18-25 : 97634

# %% [markdown]
# ### Finding how Many unique purchases done by different age groups

# %%
lst=[]
for i in df["Age"].unique():
    lst.append([i,":",len(df[df["Age"]==i]["Product_ID"].unique())])

# %%
lst
# Out:
# [['0-17', ':', 2300],
#  ['55+', ':', 2573],
#  ['26-35', ':', 3419],
#  ['46-50', ':', 3099],
#  ['51-55', ':', 2877],
#  ['36-45', ':', 3318],
#  ['18-25', ':', 3213]]

# %%
lst=[]
for i in df["Age"].unique():
    lst.append([i,len(df[df["Age"]==i]["Product_ID"].unique())])
ag_pur=pd.DataFrame(lst,columns=["Age","Unique Purchases"])

# %%
ag_pur
# Out:
#      Age  Unique Purchases
# 0   0-17              2300
# 1    55+              2573
# 2  26-35              3419
# 3  46-50              3099
# 4  51-55              2877
# 5  36-45              3318
# 6  18-25              3213

# %%
ag_pur.plot.bar(x="Age",figsize=(8,6))
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# ### Total Amount spend By each age group

# %%
df.groupby("Age")["Purchase"].sum()
# Out:
# Age
# 0-17      132659006
# 18-25     901669280
# 26-35    1999749106
# 36-45    1010649565
# 46-50     413418223
# 51-55     361908356
# 55+       197614842
# Name: Purchase, dtype: int64

# %%
df.groupby("Age")["Purchase"].sum().plot(kind="bar",figsize=(12,6),title="Amount Distribution By Age")
# Out:
# <Axes: title={'center': 'Amount Distribution By Age'}, xlabel='Age'>

# %% [markdown]
# ### Average Amount Spend by Each Age Group

# %%
df.groupby("Age")["Purchase"].mean()
# Out:
# Age
# 0-17     9020.126878
# 18-25    9235.197575
# 26-35    9314.588970
# 36-45    9401.478758
# 46-50    9284.872277
# 51-55    9620.616620
# 55+      9453.898579
# Name: Purchase, dtype: float64

# %%
df.groupby("Age")["Purchase"].mean().plot(kind="bar",figsize=(12,6),title="Average Amount Distribution By Age")
# Out:
# <Axes: title={'center': 'Average Amount Distribution By Age'}, xlabel='Age'>

# %%
df.groupby("Age")["Purchase"].mean().plot(kind="pie",autopct="%1.2f%%",figsize=(12,6),title="Average Amount Distribution By Age")
# Out:
# <Axes: title={'center': 'Average Amount Distribution By Age'}>

# %% [markdown]
# ### Finding Marital Status(married or unmarried) of peoples

# %%
df.groupby("Marital_Status").size().plot(kind="pie",autopct="%1.1f%%",figsize=(12,6),title="Average Amount Distribution By Age")
# Out:
# <Axes: title={'center': 'Average Amount Distribution By Age'}>

# %% [markdown]
# # Multi Column Analysis

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %% [markdown]
# ### comparision of age with gender how many females or males or present in certain age group

# %%
sns.set({"figure.figsize":(12,6)})
sns.countplot(x="Age",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set({"figure.figsize":(12,6)})
sns.countplot(x="Gender",hue="Age",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### comparision b/w marital_status with Gender how many females are married/unmarry and males are married or unmarried

# %%
sns.set({"figure.figsize":(6,6)})
sns.countplot(x="Gender",hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set({"figure.figsize":(6,6)})
sns.countplot(x="Marital_Status",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %% [markdown]
# ### Which City has Most Number of customers??

# %%
df.groupby("City_Category")["User_ID"].count()
# Out:
# City_Category
# A    144638
# B    226493
# C    166446
# Name: User_ID, dtype: int64

# %%
sns.set({"figure.figsize":(6,6)})
sns.countplot(x="City_Category",data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
explode=[0,1,0]
df.groupby("City_Category")["User_ID"].count().plot(kind="pie",autopct="%1.2f%%",shadow=True,explode=explode)
# Out:
# <Axes: >

# %% [markdown]
# ### finding How many purchases done in each city

# %%
df.groupby("City_Category")["Purchase"].sum()
# Out:
# City_Category
# A    1295668797
# B    2083431612
# C    1638567969
# Name: Purchase, dtype: int64

# %%
df.groupby("City_Category")["Purchase"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='City_Category'>

# %% [markdown]
# ### which city purchase expensive products?

# %% [markdown]
# Here c city buys less products but more expensive products

# %%
df.groupby("City_Category")["Purchase"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='City_Category'>

# %% [markdown]
# # Occupation and Products Analysis

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %% [markdown]
# ### finding peoples how many years stay more in current city

# %%
sns.countplot(x=df["Stay_In_Current_City_Years"])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x="Stay_In_Current_City_Years",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x="Stay_In_Current_City_Years",hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x="Stay_In_Current_City_Years",hue="Age",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x="Stay_In_Current_City_Years",hue="City_Category",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x="City_Category",hue="Age",data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x=df["Occupation"])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby("Occupation")["Purchase"].sum().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation")["Purchase"].mean().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(x="Occupation",hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x="Occupation",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby("Occupation")["Product_ID"].nunique()
# Out:
# Occupation
# 0     3243
# 1     3020
# 2     2892
# 3     2657
# 4     3174
# 5     2344
# 6     2724
# 7     3070
# 8     1026
# 9     1820
# 10    2110
# 11    2235
# 12    2664
# 13    1946
# 14    2680
# 15    2168
# 16    2863
# 17    2831
# 18    2047
# 19    2303
# 20    3147
# Name: Product_ID, dtype: int64

# %%
df.groupby("Occupation")["Product_ID"].nunique().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation")["Product_ID"].nunique().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Product_Category_1").size()
# Out:
# Product_Category_1
# 1     138353
# 2      23499
# 3      19849
# 4      11567
# 5     148592
# 6      20164
# 7       3668
# 8     112132
# 9        404
# 10      5032
# 11     23960
# 12      3875
# 13      5440
# 14      1500
# 15      6203
# 16      9697
# 17       567
# 18      3075
# dtype: int64

# %%
df.groupby("Product_Category_1").size().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1")["Purchase"].sum().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1")["Purchase"].mean().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
sns.countplot(x="Product_Category_1",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# # Combining Gender And Martial_status

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
l=[]
for i in range(len(df)):
    l.append(df["Gender"][i]+"-"+str(df["Marital_Status"][i]))
df["Martial_Gender"]=l

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   Martial_Gender
# 0            F-0
# 1            F-0
# 2            F-0
# 3            F-0
# 4            M-0

# %%
sns.countplot(df["Martial_Gender"])
# Out:
# <Axes: xlabel='count', ylabel='Martial_Gender'>

# %%
sns.countplot(x="Product_Category_1",hue="Martial_Gender",data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x="Age",hue="Martial_Gender",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="Stay_In_Current_City_Years",hue="Martial_Gender",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>
